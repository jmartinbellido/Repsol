# %% [markdown]
# # ÍNDICE
# # **ISDI Repsol D4D**
# # [Guía] Introducción a Python para Análisis de Datos - Sesión 1
#
# ### ÍNDICE
# 1. INTRODUCCIÓN A DATAFRAMES
# 2. SELECCIOR ELEMENTOS EN UN DATAFRAME
# 3. ORDENAR UN DATAFRAME
# 4. ANIDAR OPERACIONES
# 5. EJERCICIOS
#
# ### Profesor: Juan Martin Bellido (jmbelldo@isdi.education)
#
# ---

# %% [markdown]
# # 1. INTRODUCCIÓN A DATAFRAMES

# %% [markdown]
# Antes de comenzar, importamos las librerías que utilizaremos en la sesión

# %%
# Importamos librerías, en caso de error corroboramos que estén instaladas
import pandas as pd

# %% [markdown]
# ### Definiendo un dataframe en Python
# ---
# Un dataframe es una estructura de datos de dos dimensiones (filas, columnas) donde los valores se encuentran indexados.

# %% [markdown]
# #### Partiendo de una lista

# %%
# Creamos una lista
my_list = [['Maria',9.5],['Juan',8.2],['Pedro',7.2],['Antonio',6]] 
my_list
# Out:
# [['Maria', 9.5], ['Juan', 8.2], ['Pedro', 7.2], ['Antonio', 6]]

# %%
# Transformamos la lista en un dataframe utilizando la función pd.DataFrame()
df = pd.DataFrame(my_list,columns=['Asistente','Calificación'])
df

# automáticamente, el sistema creará un índice numérico
# Out:
#   Asistente  Calificación
# 0     Maria           9.5
# 1      Juan           8.2
# 2     Pedro           7.2
# 3   Antonio           6.0

# %% [markdown]
# #### Utilizando un diccionario

# %%
# Creamos un dataframe a partir de un diccionario

# definimos un diccionario
dic_cars = {'Brand': ['Honda Civic','Toyota Corolla','Ford Focus','Audi A4'],
        'Price': [22000,25000,27000,35000]
        }
# convertimos el diccionario en df
df_cars = pd.DataFrame(dic_cars)
df_cars
# Out:
#             Brand  Price
# 0     Honda Civic  22000
# 1  Toyota Corolla  25000
# 2      Ford Focus  27000
# 3         Audi A4  35000

# %% [markdown]
# ### Crear/eliminar filas

# %%
# Comenzamos creando un df a partir de una lista 
my_list = [['Maria',9.5],['Juan',8.2],['Pedro',7.2],['Antonio',6]] # creamos una lista
df = pd.DataFrame(my_list,columns=['Asistente','Calificación']) # convertimos en df

# %%
# Creamos un nuevo df y lo unimos como apéndice al df original
my_list_v2 = [['Sofia',4.5],['Clara',7.4]] # creamos una nueva lista
df2 = pd.DataFrame(my_list_v2,columns=['Asistente','Calificación']) # convertimos en df

df = df.append(df2) # utilizamos la función .append() para unir ambos dataframes, sobreescribimos el df original
df # invocamos el df

# podremos observar que el índice tendrá valores duplicados
# Out:
#   Asistente  Calificación
# 0     Maria           9.5
# 1      Juan           8.2
# 2     Pedro           7.2
# 3   Antonio           6.0
# 0     Sofia           4.5
# 1     Clara           7.4

# %%
# Podemos elimiinar observaciones (filas) utilizando la función .drop()
df = df.drop(1) # eliminamos las filas con el índice "1"
df
# Out:
#   Asistente  Calificación
# 0     Maria           9.5
# 2     Pedro           7.2
# 3   Antonio           6.0
# 0     Sofia           4.5

# %%
# Es recomendable configurar índices con valores únicos (sin duplicados)
df = df.set_index('Asistente') # utilizamos la función .set_index() para redefinir el índice del df
df
# Out:
#            Calificación
# Asistente
# Maria               9.5
# Pedro               7.2
# Antonio             6.0
# Sofia               4.5

# %%
df = df.drop('Pedro') # eliminamos las filas con el índice "Pedro"
df
# Out:
#            Calificación
# Asistente
# Maria               9.5
# Antonio             6.0
# Sofia               4.5

# %% [markdown]
# ### Importar un dataframe
# ---

# %% [markdown]
# Podemos importar un dataset al entorno de distintas fuentes
#
# ```
# df = pd.read_csv("path")
# df = pd.read_csv("path",index_col='column')
# ```
# Notas,
#
# *   el path puede ser una URL o ruta local al objeto
# *   podemos utilizar el parámetro *index_col* para especificar index al importar objeto

# %%
# Importamos dataframe desde una URL y lo almacenamos en un objeto
df_jamesbond = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv")
df_jamesbond.head() # utilizamos la función head() para visualizar las primeras filas
# Out:
#                     Film  Year  ... Budget Bond Actor Salary
# 0                 Dr. No  1962  ...    7.0               0.6
# 1  From Russia with Love  1963  ...   12.6               1.6
# 2             Goldfinger  1964  ...   18.6               3.2
# 3            Thunderball  1965  ...   41.9               4.7
# 4          Casino Royale  1967  ...   85.0               NaN
#
# [5 rows x 7 columns]

# %%
# Importamos dataframe, desde la una URL. Especificamos columna "Film" como índice utilizando el parámetro index_col
df_jamesbond = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv",index_col="Film")
df_jamesbond.head()
# Out:
#                        Year         Actor  ... Budget  Bond Actor Salary
# Film                                       ...
# Dr. No                 1962  Sean Connery  ...    7.0                0.6
# From Russia with Love  1963  Sean Connery  ...   12.6                1.6
# Goldfinger             1964  Sean Connery  ...   18.6                3.2
# Thunderball            1965  Sean Connery  ...   41.9                4.7
# Casino Royale          1967   David Niven  ...   85.0                NaN
#
# [5 rows x 6 columns]

# %% [markdown]
# Podemos redefinir un índice utilizando el method *set_index()*.
#
#
# ```
# object.set_index("column")
# ```

# %%
df_jamesbond.set_index("Actor")
# Out:
#                 Year            Director  Box Office  Budget  Bond Actor Salary
# Actor
# Roger Moore     1985           John Glen       275.2    54.5                9.1
# Daniel Craig    2006     Martin Campbell       581.5   145.3                3.3
# David Niven     1967          Ken Hughes       315.0    85.0                NaN
# Sean Connery    1971        Guy Hamilton       442.5    34.7                5.8
# Pierce Brosnan  2002        Lee Tamahori       465.4   154.2               17.9
# Sean Connery    1962       Terence Young       448.8     7.0                0.6
# Roger Moore     1981           John Glen       449.4    60.2                NaN
# Sean Connery    1963       Terence Young       543.8    12.6                1.6
# Pierce Brosnan  1995     Martin Campbell       518.5    76.9                5.1
# Sean Connery    1964        Guy Hamilton       820.4    18.6                3.2
# Timothy Dalton  1989           John Glen       250.9    56.7                7.9
# Roger Moore     1973        Guy Hamilton       460.3    30.8                NaN
# Roger Moore     1979       Lewis Gilbert       535.0    91.5                NaN
# Sean Connery    1983      Irvin Kershner       380.0    86.0                NaN
# Roger Moore     1983           John Glen       373.8    53.9                7.8
# George Lazenby  1969       Peter R. Hunt       291.5    37.3                0.6
# Daniel Craig    2008        Marc Forster       514.2   181.4                8.1
# Daniel Craig    2012          Sam Mendes       943.5   170.2               14.5
# Daniel Craig    2015          Sam Mendes       726.7   206.3                NaN
# Timothy Dalton  1987           John Glen       313.5    68.8                5.2
# Roger Moore     1974        Guy Hamilton       334.0    27.7                NaN
# Roger Moore     1977       Lewis Gilbert       533.0    45.1                NaN
# Pierce Brosnan  1999       Michael Apted       439.5   158.3               13.5
# Sean Connery    1965       Terence Young       848.1    41.9                4.7
# Pierce Brosnan  1997  Roger Spottiswoode       463.2   133.9               10.0
# Sean Connery    1967       Lewis Gilbert       514.2    59.9                4.4

# %% [markdown]
# ### Exportar un dataframe
# ---

# %% [markdown]
# Exportamos dataframes en formato CSV utilizando el método *.to_csv()*
#
#
# ```
# df.to_csv("path+file_name.csv",index=False)
# ```

# %%
# Importamos un dataframe, lo modificamos y exportamos
df_jamesbond = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv",index_col="Film")
df_new = df_jamesbond["Actor"]
df_new.to_csv("my_df.csv")

# %% [markdown]
# # 2. SELECCIONAR ELEMENTOS EN UN DATAFRAME

# %%
# Antes de comenzar con la sección, importamos un df, especificamos index y ordenamos
df_jamesbond = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv",index_col="Film")
df_jamesbond
# Out:
#                                  Year  ... Bond Actor Salary
# Film                                   ...
# Dr. No                           1962  ...               0.6
# From Russia with Love            1963  ...               1.6
# Goldfinger                       1964  ...               3.2
# Thunderball                      1965  ...               4.7
# Casino Royale                    1967  ...               NaN
# You Only Live Twice              1967  ...               4.4
# On Her Majesty's Secret Service  1969  ...               0.6
# Diamonds Are Forever             1971  ...               5.8
# Live and Let Die                 1973  ...               NaN
# The Man with the Golden Gun      1974  ...               NaN
# The Spy Who Loved Me             1977  ...               NaN
# Moonraker                        1979  ...               NaN
# For Your Eyes Only               1981  ...               NaN
# Never Say Never Again            1983  ...               NaN
# Octopussy                        1983  ...               7.8
# A View to a Kill                 1985  ...               9.1
# The Living Daylights             1987  ...               5.2
# Licence to Kill                  1989  ...               7.9
# GoldenEye                        1995  ...               5.1
# Tomorrow Never Dies              1997  ...              10.0
# The World Is Not Enough          1999  ...              13.5
# Die Another Day                  2002  ...              17.9
# Casino Royale                    2006  ...               3.3
# Quantum of Solace                2008  ...               8.1
# Skyfall                          2012  ...              14.5
# Spectre                          2015  ...               NaN
#
# [26 rows x 6 columns]

# %% [markdown]
# ### Seleccionar columnas en un dataframe
# ---
# Podemos seleccionar columnas en un dataframe utilizando la siguiente sintaxis,
#
# ```
# object["column"]
# ```

# %%
# Selecccionamos una columna
df_jamesbond["Director"]

# notar que el dataframe siempre mantendrá el índice
# Out:
# Film
# A View to a Kill                            John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# Skyfall                                    Sam Mendes
# Spectre                                    Sam Mendes
# The Living Daylights                        John Glen
# The Man with the Golden Gun              Guy Hamilton
# The Spy Who Loved Me                    Lewis Gilbert
# The World Is Not Enough                 Michael Apted
# Thunderball                             Terence Young
# Tomorrow Never Dies                Roger Spottiswoode
# You Only Live Twice                     Lewis Gilbert
# Name: Director, dtype: object

# %%
# A continuación, incorporamos un list (vector) dentro del parámetro para elegir más de una columna
df_jamesbond[["Year","Director"]]
# Out:
#                                  Year            Director
# Film
# A View to a Kill                 1985           John Glen
# Casino Royale                    2006     Martin Campbell
# Casino Royale                    1967          Ken Hughes
# Diamonds Are Forever             1971        Guy Hamilton
# Die Another Day                  2002        Lee Tamahori
# Dr. No                           1962       Terence Young
# For Your Eyes Only               1981           John Glen
# From Russia with Love            1963       Terence Young
# GoldenEye                        1995     Martin Campbell
# Goldfinger                       1964        Guy Hamilton
# Licence to Kill                  1989           John Glen
# Live and Let Die                 1973        Guy Hamilton
# Moonraker                        1979       Lewis Gilbert
# Never Say Never Again            1983      Irvin Kershner
# Octopussy                        1983           John Glen
# On Her Majesty's Secret Service  1969       Peter R. Hunt
# Quantum of Solace                2008        Marc Forster
# Skyfall                          2012          Sam Mendes
# Spectre                          2015          Sam Mendes
# The Living Daylights             1987           John Glen
# The Man with the Golden Gun      1974        Guy Hamilton
# The Spy Who Loved Me             1977       Lewis Gilbert
# The World Is Not Enough          1999       Michael Apted
# Thunderball                      1965       Terence Young
# Tomorrow Never Dies              1997  Roger Spottiswoode
# You Only Live Twice              1967       Lewis Gilbert

# %% [markdown]
# ### Seleccionar elementos utilizando el índice
# ---

# %% [markdown]
# El method *loc()* permite seleccionar elementos de un dataframe a partir del nombre del índice.
#
#
# ```
# object.loc[row_list,column_list]
# object.loc[[row_1,row_2,...],[col_1,col_2,...]]
# ```

# %%
# A continuación, utilizaremos el método .loc[] para seleccionar elementos en nuestro df
df_jamesbond.loc[["From Russia with Love","Goldfinger"],:] # seleccionamos dos filas, todas las columnas
# Out:
#                        Year         Actor  ... Budget  Bond Actor Salary
# Film                                       ...
# From Russia with Love  1963  Sean Connery  ...   12.6                1.6
# Goldfinger             1964  Sean Connery  ...   18.6                3.2
#
# [2 rows x 6 columns]

# %%
# importamos un df, especificamos index y ordenamos
df_jamesbond.loc["From Russia with Love":"Goldfinger",["Year","Director"]] # importarmos un rango de filas, dos columnas
# Out:
#                        Year         Director
# Film
# From Russia with Love  1963    Terence Young
# GoldenEye              1995  Martin Campbell
# Goldfinger             1964     Guy Hamilton

# %% [markdown]
# ### Seleccionar elementos utilizando posición del índice
# ---

# %% [markdown]
# El method *iloc()* permite seleccionar elementos en un dataframe, a partir de la posición relativa de filas y columnas dentro de un dataset.
#
# ```
# object.iloc[row_position,col_position]
# ```

# %%
# A continuación, seleccionamos elementos según su posición en el dataframe
df_jamesbond.iloc[:5,[1,3,5]] # seleccionamos todas las filas hasta la 5ta; columnas 1,3,5
# Out:
#                                Actor  Box Office  Bond Actor Salary
# Film
# A View to a Kill         Roger Moore       275.2                9.1
# Casino Royale           Daniel Craig       581.5                3.3
# Casino Royale            David Niven       315.0                NaN
# Diamonds Are Forever    Sean Connery       442.5                5.8
# Die Another Day       Pierce Brosnan       465.4               17.9

# %% [markdown]
# ### Seleccionar elementos dentro de un dataframe a partir de un vector booleano
# ---

# %% [markdown]
# Podemos seleccionar elementos utilizando un vector booleano (true, false).
#
#
# ```
# object[[True,False,False]]
# ```

# %%
# Creamos un dataframe
dic_cars = {'Brand': ['Honda Civic','Toyota Corolla','Ford Focus','Audi A4'],
        'Price': [22000,25000,27000,35000]
        }

df_cars = pd.DataFrame(dic_cars)
df_cars
# Out:
#             Brand  Price
# 0     Honda Civic  22000
# 1  Toyota Corolla  25000
# 2      Ford Focus  27000
# 3         Audi A4  35000

# %%
# Podríamos seleccionar elementos, incorporando un vector booleano (una lista con valores booleanos)
df_cars[[True,False,False,True]] # seleccionamos columnas primera y cuarta
# Out:
#          Brand  Price
# 0  Honda Civic  22000
# 3      Audi A4  35000

# %% [markdown]
# ### Seleccionar elementos dentro de un dataframe a partir de condiciones lógicas
# ---
#
# Como paso siguiente, construiremos condiciones específicas que utilizaremos para filtrar nuestro dataframe.
#
# ```
# object[object[condition]]
# ```

# %%
# A continuación, seleccionaremos elementos del dataframe a partir de condiciones lógicas
cond = df_jamesbond["Budget"]>100 # creamos un objeto con una prueba lógica, esto nos devolverá un vector booleano
cond
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                       True
# Casino Royale                      False
# Diamonds Are Forever               False
# Die Another Day                     True
# Dr. No                             False
# For Your Eyes Only                 False
# From Russia with Love              False
# GoldenEye                          False
# Goldfinger                         False
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Never Say Never Again              False
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                   True
# Skyfall                             True
# Spectre                             True
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough             True
# Thunderball                        False
# Tomorrow Never Dies                 True
# You Only Live Twice                False
# Name: Budget, dtype: bool

# %%
# Utilizaremos el objeto que almacena el vector booleano como parámetro en el df
df_jamesbond[cond] # filtramos el df

# %%
# creamos condiciones y las almacenamos en objetos
cond_1 = df_jamesbond["Budget"]>100
cond_2 = df_jamesbond["Actor"]=='Daniel Craig'
cond_3 = df_jamesbond["Year"]<1965

df_jamesbond[cond_1 & cond_2 | cond_3] # seleccionamos filas que cumplen con múltiples condiciones
# Out:
#                        Year         Actor  ... Budget  Bond Actor Salary
# Film                                       ...
# Casino Royale          2006  Daniel Craig  ...  145.3                3.3
# Dr. No                 1962  Sean Connery  ...    7.0                0.6
# From Russia with Love  1963  Sean Connery  ...   12.6                1.6
# Goldfinger             1964  Sean Connery  ...   18.6                3.2
# Quantum of Solace      2008  Daniel Craig  ...  181.4                8.1
# Skyfall                2012  Daniel Craig  ...  170.2               14.5
# Spectre                2015  Daniel Craig  ...  206.3                NaN
#
# [7 rows x 6 columns]

# %%
# combinamos métodos para seleccinar filas y columnas
df_jamesbond[cond_1 & cond_2 | cond_3][['Year','Director','Actor']]
# Out:
#                        Year         Director         Actor
# Film
# Casino Royale          2006  Martin Campbell  Daniel Craig
# Dr. No                 1962    Terence Young  Sean Connery
# From Russia with Love  1963    Terence Young  Sean Connery
# Goldfinger             1964     Guy Hamilton  Sean Connery
# Quantum of Solace      2008     Marc Forster  Daniel Craig
# Skyfall                2012       Sam Mendes  Daniel Craig
# Spectre                2015       Sam Mendes  Daniel Craig

# %% [markdown]
# ### Funciones útiles para filtrar
# ---

# %% [markdown]
# #### isin(): filtrar por múltiples valores

# %%
# podemos utilizar el método .isin() para filtrar por múltiples valores en una variable categórica
cond = df_jamesbond['Director'].isin(['Martin Campbell','Terence Young']) # filtramos por más de un valor para una variable categórica

df_jamesbond[cond]
# Out:
#                        Year           Actor  ... Budget  Bond Actor Salary
# Film                                         ...
# Casino Royale          2006    Daniel Craig  ...  145.3                3.3
# Dr. No                 1962    Sean Connery  ...    7.0                0.6
# From Russia with Love  1963    Sean Connery  ...   12.6                1.6
# GoldenEye              1995  Pierce Brosnan  ...   76.9                5.1
# Thunderball            1965    Sean Connery  ...   41.9                4.7
#
# [5 rows x 6 columns]

# %% [markdown]
# #### str.contains(): identificar patrones de texto

# %%
# importamos un df, en este caso no configuraremos índice
df_jamesbond = pd.read_csv('https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv')
df_jamesbond.head()
# Out:
#                     Film  Year  ... Budget Bond Actor Salary
# 0                 Dr. No  1962  ...    7.0               0.6
# 1  From Russia with Love  1963  ...   12.6               1.6
# 2             Goldfinger  1964  ...   18.6               3.2
# 3            Thunderball  1965  ...   41.9               4.7
# 4          Casino Royale  1967  ...   85.0               NaN
#
# [5 rows x 7 columns]

# %%
# creamos condiciones para reconocer patrones específicos de texto
cond_1 = df_jamesbond['Film'].str.contains('love', regex=False, case=False)
cond_2 = df_jamesbond['Film'].str.contains('die', regex=False, case=False)

# creamos una condición, reconociendo un patrón en un campo de tipo texto
df_jamesbond[cond_1 | cond_2]
# Out:
#                      Film  Year  ... Budget Bond Actor Salary
# 1   From Russia with Love  1963  ...   12.6               1.6
# 8        Live and Let Die  1973  ...   30.8               NaN
# 10   The Spy Who Loved Me  1977  ...   45.1               NaN
# 19    Tomorrow Never Dies  1997  ...  133.9              10.0
# 21        Die Another Day  2002  ...  154.2              17.9
#
# [5 rows x 7 columns]

# %% [markdown]
# # ORDENAR UN DATAFRAME
# El method *sort_index()* ordena el dataframe según el campo especificado como índice; por defecto lo hace en sentido ascendente.
#
# ```
# object.sort_index(ascending=True/False)
# ```

# %%
df_jamesbond = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv",index_col="Film").sort_index()
df_jamesbond.head()
# Out:
#                       Year           Actor  ... Budget  Bond Actor Salary
# Film                                        ...
# A View to a Kill      1985     Roger Moore  ...   54.5                9.1
# Casino Royale         2006    Daniel Craig  ...  145.3                3.3
# Casino Royale         1967     David Niven  ...   85.0                NaN
# Diamonds Are Forever  1971    Sean Connery  ...   34.7                5.8
# Die Another Day       2002  Pierce Brosnan  ...  154.2               17.9
#
# [5 rows x 6 columns]

# %% [markdown]
# El method *sort_values()* permite especificar criterios para ordenar un dataframe.
#
#
# ```
# object.sort_values(column,ascending=True/False)
# ```

# %%
# importamos un df y ordenamos según un campo que no es su índice
df_jamesbond = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv",index_col="Film")

df_jamesbond.sort_values("Bond Actor Salary",ascending=False)
# Out:
#                                  Year  ... Bond Actor Salary
# Film                                   ...
# Die Another Day                  2002  ...              17.9
# Skyfall                          2012  ...              14.5
# The World Is Not Enough          1999  ...              13.5
# Tomorrow Never Dies              1997  ...              10.0
# A View to a Kill                 1985  ...               9.1
# Quantum of Solace                2008  ...               8.1
# Licence to Kill                  1989  ...               7.9
# Octopussy                        1983  ...               7.8
# Diamonds Are Forever             1971  ...               5.8
# The Living Daylights             1987  ...               5.2
# GoldenEye                        1995  ...               5.1
# Thunderball                      1965  ...               4.7
# You Only Live Twice              1967  ...               4.4
# Casino Royale                    2006  ...               3.3
# Goldfinger                       1964  ...               3.2
# From Russia with Love            1963  ...               1.6
# On Her Majesty's Secret Service  1969  ...               0.6
# Dr. No                           1962  ...               0.6
# Casino Royale                    1967  ...               NaN
# Live and Let Die                 1973  ...               NaN
# The Man with the Golden Gun      1974  ...               NaN
# The Spy Who Loved Me             1977  ...               NaN
# Moonraker                        1979  ...               NaN
# For Your Eyes Only               1981  ...               NaN
# Never Say Never Again            1983  ...               NaN
# Spectre                          2015  ...               NaN
#
# [26 rows x 6 columns]

# %%
# ordenamos el dataframe en función de dos criterios
df_jamesbond.sort_values(["Actor","Year"],ascending=[True,False])
# Out:
#                                  Year  ... Bond Actor Salary
# Film                                   ...
# Spectre                          2015  ...               NaN
# Skyfall                          2012  ...              14.5
# Quantum of Solace                2008  ...               8.1
# Casino Royale                    2006  ...               3.3
# Casino Royale                    1967  ...               NaN
# On Her Majesty's Secret Service  1969  ...               0.6
# Die Another Day                  2002  ...              17.9
# The World Is Not Enough          1999  ...              13.5
# Tomorrow Never Dies              1997  ...              10.0
# GoldenEye                        1995  ...               5.1
# A View to a Kill                 1985  ...               9.1
# Octopussy                        1983  ...               7.8
# For Your Eyes Only               1981  ...               NaN
# Moonraker                        1979  ...               NaN
# The Spy Who Loved Me             1977  ...               NaN
# The Man with the Golden Gun      1974  ...               NaN
# Live and Let Die                 1973  ...               NaN
# Never Say Never Again            1983  ...               NaN
# Diamonds Are Forever             1971  ...               5.8
# You Only Live Twice              1967  ...               4.4
# Thunderball                      1965  ...               4.7
# Goldfinger                       1964  ...               3.2
# From Russia with Love            1963  ...               1.6
# Dr. No                           1962  ...               0.6
# Licence to Kill                  1989  ...               7.9
# The Living Daylights             1987  ...               5.2
#
# [26 rows x 6 columns]

# %% [markdown]
# # ANIDAR OPERACIONES
# Python cuenta con un método nativo para anidar operaciones (*method chaining*). Podemos realizar múltiples operaciones utilizando methods uno tras otro; opcionalmente, incorporando un *\* permite anidar operaciones en distintas líneas de código

# %%
pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/jamesbond.csv",index_col="Film")\ # importamos dataset
  .sort_values(["Actor"],ascending =False)\ # ordenamos dataset en función de columna "Actor" (descendiente)
  .iloc[:5,:] # seleccionamos primeras tres filas
# Out:
#                        Year           Actor  ... Budget  Bond Actor Salary
# Film                                         ...
# Licence to Kill        1989  Timothy Dalton  ...   56.7                7.9
# The Living Daylights   1987  Timothy Dalton  ...   68.8                5.2
# Dr. No                 1962    Sean Connery  ...    7.0                0.6
# Diamonds Are Forever   1971    Sean Connery  ...   34.7                5.8
# From Russia with Love  1963    Sean Connery  ...   12.6                1.6
#
# [5 rows x 6 columns]

# %% [markdown]
# # EJERCICIOS
# *Nota: la solución a los ejercicios será enviada al finalizar la sesión.*

# %% [markdown]
# ##### EX 1
#
# Dataset > https://data-wizards.s3.amazonaws.com/datasets/dataset_star_wars.csv
#
# ##### EX 1.A. Importar dataframe. Seleccionar columnas "name", "homeworld", "species" para las primeras 10 filas del dataframe.
#
# ##### EX 1.B. Seleccionar personajes que a) no sean *species* hombre y b) sean *homeworld* Naboo, Endor o Kashyyyk.
# ---

# %%
import pandas as pd

# %%
# EX 1.A
df_starwars = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/dataset_star_wars.csv",index_col="name")
df_starwars.head()
# Out:
#                 height  mass hair_color  ...  gender    homeworld         species
# name                                     ...
# Mon Mothma       150.0   NaN     auburn  ...  female    Chandrila           Human
# Yoda              66.0  17.0      white  ...    male          NaN  Yoda's species
# Tion Medon       206.0  80.0       none  ...    male       Utapau          Pau'an
# Ratts Tyerell     79.0  15.0       none  ...    male  Aleen Minor          Aleena
# Luke Skywalker   172.0  77.0      blond  ...    male     Tatooine           Human
#
# [5 rows x 9 columns]

# %%
# EX 1.A
df_starwars[["homeworld","species"]].iloc[:10,:]
# Out:
#                       homeworld         species
# name
# Mon Mothma            Chandrila           Human
# Yoda                        NaN  Yoda's species
# Tion Medon               Utapau          Pau'an
# Ratts Tyerell       Aleen Minor          Aleena
# Luke Skywalker         Tatooine           Human
# R2-D2                     Naboo           Droid
# Beru Whitesun lars     Tatooine           Human
# Chewbacca              Kashyyyk         Wookiee
# Raymus Antilles        Alderaan           Human
# Mace Windu           Haruun Kal           Human

# %%
# EX 1.B
## lo solucionaremos sin utilizar el método .isin
cond_1 = df_starwars["species"]!='Human'
cond_2 = df_starwars["homeworld"]=='Naboo'
cond_3 = df_starwars["homeworld"]=='Endor'
cond_4 = df_starwars["homeworld"]=='Kashyyyk'

df_starwars[cond_1 & (cond_2 | cond_3 | cond_4)]
# Out:
#                        height   mass hair_color  ... gender homeworld  species
# name                                             ...
# R2-D2                    96.0   32.0        NaN  ...    NaN     Naboo    Droid
# Chewbacca               228.0  112.0      brown  ...   male  Kashyyyk  Wookiee
# Rugor Nass              206.0    NaN       none  ...   male     Naboo   Gungan
# Tarfful                 234.0  136.0      brown  ...   male  Kashyyyk  Wookiee
# Quarsh Panaka           183.0    NaN      black  ...   male     Naboo      NaN
# Roos Tarpals            224.0   82.0       none  ...   male     Naboo   Gungan
# Wicket Systri Warrick    88.0   20.0      brown  ...   male     Endor     Ewok
# Ric Olié                183.0    NaN      brown  ...   male     Naboo      NaN
# Jar Jar Binks           196.0   66.0       none  ...   male     Naboo   Gungan
#
# [9 rows x 9 columns]

# %%
# EX 1.B
## lo solucionamos utilizando el método .isin
cond_1 = df_starwars["species"]!='Human'
cond_2 = df_starwars["homeworld"].isin(["Naboo","Endor","Kashyyyk"])

df_starwars[cond_1 & cond_2]
# Out:
#                        height   mass hair_color  ... gender homeworld  species
# name                                             ...
# R2-D2                    96.0   32.0        NaN  ...    NaN     Naboo    Droid
# Chewbacca               228.0  112.0      brown  ...   male  Kashyyyk  Wookiee
# Rugor Nass              206.0    NaN       none  ...   male     Naboo   Gungan
# Tarfful                 234.0  136.0      brown  ...   male  Kashyyyk  Wookiee
# Quarsh Panaka           183.0    NaN      black  ...   male     Naboo      NaN
# Roos Tarpals            224.0   82.0       none  ...   male     Naboo   Gungan
# Wicket Systri Warrick    88.0   20.0      brown  ...   male     Endor     Ewok
# Ric Olié                183.0    NaN      brown  ...   male     Naboo      NaN
# Jar Jar Binks           196.0   66.0       none  ...   male     Naboo   Gungan
#
# [9 rows x 9 columns]

# %%
# EX 1.C
df_starwars = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/dataset_star_wars.csv",index_col="name")
df_starwars.sort_index().iloc[0:10,][["homeworld","species"]]
# Out:
#                      homeworld       species
# name
# Ackbar                Mon Cala  Mon Calamari
# Adi Gallia           Coruscant    Tholothian
# Anakin Skywalker      Tatooine         Human
# Arvel Crynyd               NaN         Human
# Ayla Secura             Ryloth       Twi'lek
# BB8                        NaN         Droid
# Bail Prestor Organa   Alderaan         Human
# Barriss Offee           Mirial      Mirialan
# Ben Quadinaros            Tund         Toong
# Beru Whitesun lars    Tatooine         Human

# %% [markdown]
# ##### EX 2
# Dataset > https://data-wizards.s3.amazonaws.com/datasets/movies.csv
#
#
# ##### Importar dataframe. Seleccionar columnas *country*, *director_name*, *imdb_score* para las primeras 10 filas del dataframe.
# ---

# %%
df_movies = pd.read_csv('https://data-wizards.s3.amazonaws.com/datasets/movies.csv',index_col='movie_title')
df_movies.head()
# Out:
#                                             color  ... movie_facebook_likes
# movie_title                                        ...
# Avatar                                      Color  ...                33000
# Pirates of the Caribbean: At World's End    Color  ...                    0
# Spectre                                     Color  ...                85000
# The Dark Knight Rises                       Color  ...               164000
# Star Wars: Episode VII - The Force Awakens    NaN  ...                    0
#
# [5 rows x 27 columns]

# %%
cond_1_1 = df_movies['country']!='USA'
cond_1_2 = df_movies['imdb_score']>8.5

cond_2 = df_movies['director_name'].isin(['James Cameron','Peter Jackson','Tim Burton'])

df_movies[(cond_1_1 & cond_1_2)|cond_2][['country','director_name','imdb_score']]
# Out:
#                                                        country  ... imdb_score
# movie_title                                                     ...
# Avatar                                                     USA  ...        7.9
# The Hobbit: The Battle of the Five Armies          New Zealand  ...        7.5
# The Hobbit: The Desolation of Smaug                        USA  ...        7.9
# King Kong                                          New Zealand  ...        7.2
# Titanic                                                    USA  ...        7.7
# Alice in Wonderland                                        USA  ...        6.5
# The Hobbit: An Unexpected Journey                          USA  ...        7.9
# Charlie and the Chocolate Factory                          USA  ...        6.7
# Dark Shadows                                               USA  ...        6.2
# The Lord of the Rings: The Fellowship of the Ring  New Zealand  ...        8.8
# Planet of the Apes                                         USA  ...        5.7
# Terminator 2: Judgment Day                                 USA  ...        8.5
# True Lies                                                  USA  ...        7.2
# The Lovely Bones                                           USA  ...        6.7
# The Lord of the Rings: The Return of the King              USA  ...        8.9
# The Lord of the Rings: The Two Towers                      USA  ...        8.7
# Batman Returns                                             USA  ...        7.0
# Mars Attacks!                                              USA  ...        6.3
# Big Fish                                                   USA  ...        8.0
# The Abyss                                                  USA  ...        7.6
# Frankenweenie                                              USA  ...        7.0
# Batman                                                     USA  ...        7.6
# Luther                                                      UK  ...        8.6
# Corpse Bride                                               USA  ...        7.4
# Edward Scissorhands                                        USA  ...        7.9
# Spirited Away                                            Japan  ...        8.6
# Ed Wood                                                    USA  ...        7.9
# Aliens                                                     USA  ...        8.4
# Beetlejuice                                                USA  ...        7.5
# Towering Inferno                                        Canada  ...        9.5
# Dekalog                                                 Poland  ...        9.1
# Big Eyes                                                   USA  ...        7.0
# The Terminator                                              UK  ...        8.1
# Gomorrah                                                 Italy  ...        8.7
# Once Upon a Time in the West                             Italy  ...        8.6
# Heavenly Creatures                                 New Zealand  ...        7.4
# City of God                                             Brazil  ...        8.7
# Queen of the Mountains                              Kyrgyzstan  ...        8.7
# The Good, the Bad and the Ugly                           Italy  ...        8.9
# Seven Samurai                                            Japan  ...        8.7
#
# [40 rows x 3 columns]

# %% [markdown]
# ##### EX 3
# Dataset > https://data-wizards.s3.amazonaws.com/datasets/fortune1000.csv
#
#
# Importar dataframe. Extraer top 10 empresas con mayor facturación (*revenue*) del sector tecnología.

# %%
df_fortune = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/fortune1000.csv",index_col="Company")
df_fortune.head()
# Out:
#                     Rank       Sector  ... Profits Employees
# Company                                ...
# Walmart                1    Retailing  ...   14694   2300000
# Exxon Mobil            2       Energy  ...   16150     75600
# Apple                  3   Technology  ...   53394    110000
# Berkshire Hathaway     4   Financials  ...   24083    331000
# McKesson               5  Health Care  ...    1476     70400
#
# [5 rows x 7 columns]

# %%
df_fortune[df_fortune['Sector']=='Technology'].sort_values('Revenue',ascending=False).iloc[:10,]
# Out:
#                Rank      Sector  ... Profits Employees
# Company                          ...
# Apple             3  Technology  ...   53394    110000
# Amazon.com       18  Technology  ...     596    230800
# HP               20  Technology  ...    4554    287000
# Microsoft        25  Technology  ...   12193    118000
# IBM              31  Technology  ...   13190    411798
# Alphabet         36  Technology  ...   16348     61814
# Intel            51  Technology  ...   11420    107300
# Cisco Systems    54  Technology  ...    8981     71833
# Oracle           77  Technology  ...    9938    132000
# Qualcomm        110  Technology  ...    5271     33000
#
# [10 rows x 7 columns]

# %% [markdown]
# ##### EX 4
# Dataset > https://data-wizards.s3.amazonaws.com/datasets/movies.csv
#
#
# ##### Importar dataframe. Extraer top 10 películas de Sci-Fi con mayor IMDB score, seleccionar únicamente campos *title_year*, *director_name* y *imdb_score*.
# ---

# %%
df_movies = pd.read_csv('https://data-wizards.s3.amazonaws.com/datasets/movies.csv',index_col='movie_title')
df_movies.head()
# Out:
#                                             color  ... movie_facebook_likes
# movie_title                                        ...
# Avatar                                      Color  ...                33000
# Pirates of the Caribbean: At World's End    Color  ...                    0
# Spectre                                     Color  ...                85000
# The Dark Knight Rises                       Color  ...               164000
# Star Wars: Episode VII - The Force Awakens    NaN  ...                    0
#
# [5 rows x 27 columns]

# %%
# creamos una condición, reconociendo un patrón en un campo de tipo texto
cond_1 = df_movies['genres'].str.contains('Sci-Fi', regex=False, case=False)

# filtramos por filas que cumplen la condiciñón, ordenamos, seleccionamos primeras 10 entradas y seleccionamos determinadas columnas
df_movies[cond_1].sort_values('imdb_score',ascending=False).iloc[:10,][['title_year','director_name','imdb_score']]
# Out:
#                                                 title_year  ... imdb_score
# movie_title                                                 ...
# Daredevil                                              NaN  ...        8.8
# Star Wars: Episode V - The Empire Strikes Back      1980.0  ...        8.8
# Inception                                           2010.0  ...        8.8
# The Matrix                                          1999.0  ...        8.7
# Star Wars: Episode IV - A New Hope                  1977.0  ...        8.7
# Interstellar                                        2014.0  ...        8.6
# Outlander                                              NaN  ...        8.5
# Alien                                               1979.0  ...        8.5
# The Prestige                                        2006.0  ...        8.5
# Terminator 2: Judgment Day                          1991.0  ...        8.5
#
# [10 rows x 3 columns]

# %% [markdown]
# ##### EX 5
# Dataset > https://data-wizards.s3.amazonaws.com/datasets/dataset_star_wars.csv
#
# ##### Seleccionar diez primeros personajes, según orden alfabético. Ordenar personajes según altura (descendente). Desplegar únicamente columnas *name*, *homeworld*, *species*.
# ---

# %%
# Para resolver este ejercicio debemos ordenar, filtrar y volver a ordenar
df_starwars = pd.read_csv("https://data-wizards.s3.amazonaws.com/datasets/dataset_star_wars.csv",index_col="name")
df_starwars.sort_index().iloc[0:10,].sort_values("height",ascending=False).loc[:,["homeworld","species"]]
